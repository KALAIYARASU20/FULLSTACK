# %%
print("Welcome to your simple Quiz chatbot!")
print("Answer the questions by typing a, b, c or d\n")
score = 0

questions = [
    {
        "Question": "1. What is the national bird of India?",
        "a": "Peacock",
        "b": "Sparrow",
        "c": "Eagle",
        "d": "Parrot",
        "Answer": "a"
    },
    {
        "Question": "2. Which planet is known as the Red Planet?",
        "a": "Earth",
        "b": "Mars",
        "c": "Jupiter",
        "d": "Venus",
        "Answer": "b"
    },
    {
        "Question": "3. Who is known as the Father of the Nation in India?",
        "a": "Subhash Chandra Bose",
        "b": "Jawaharlal Nehru",
        "c": "Mahatma Gandhi",
        "d": "Bhagat Singh",
        "Answer": "c"
    },
    {
        "Question": "4. How many states are there in India?",
        "a": "28",
        "b": "30",
        "c": "25",
        "d": "27",
        "Answer": "a"
    },
    {
        "Question": "5. Which is the largest ocean in the world?",
        "a": "Indian Ocean",
        "b": "Arctic Ocean",
        "c": "Pacific Ocean",
        "d": "Atlantic Ocean",
        "Answer": "c"
    },
    {
       "Question": "6. Who invented the light bulb?",
       "a": "Alexander Graham Bell",
       "b": "Thomas Alva Edison",
       "c": "Albert Einstein",
       "d": "Isaac Newton",
       "Answer": "b"
    },
    {
       "Question": "7. What is the chemical formula for water?",
        "a": "CO2",
        "b": "H2O",
        "c": "O2",
        "d": "NaCl",
        "Answer": "b"
   },
   {
        "Question": "8. Which is the longest river in the world?",
        "a": "Ganga",
        "b": "Amazon",
        "c": "Nile",
        "d": "Yangtze",
        "Answer": "c"
   },
   {
        "Question": "9. Who wrote the Indian national anthem?",
        "a": "Sarojini Naidu",
        "b": "Rabindranath Tagore",
        "c": "Bankim Chandra Chatterjee",
        "d": "Subramania Bharati",
        "Answer": "b"
   },
   {
        "Question": "10. Which is the smallest continent in the world?",
        "a": "Asia",
        "b": "Africa",
        "c": "Australia",
        "d": "Europe",
        "Answer": "c"
   }

]

for q in Question:
    print(q["Question"])
    print("a)",q["a"])
    print("b)",q["b"])
    print("c)",q["c"])
    print("d)",q["d"])

    user_ans = input("Your answer: ").lower()

    if user_ans == q["Answer"]:
        print("Correct\n")
        score += 1
    else:
        print("Wrong! Correct answer is:", q["Answer"], "\n")
print("Your final score:", score, "/", len(Question))
# Out:
# Welcome to your simple Quiz chatbot!
# Answer the questions by typing a, b, c or d
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 89
#       3 score = 0
#       5 questions = [
#       6     {
#       7         "Question": "1. What is the national bird of India?",
#    (...)     86
#      87 ]
# ---> 89 for q in Question:
#      90     print(q["Question"])
#      91     print("a)",q["a"])
#
# NameError: name 'Question' is not defined
